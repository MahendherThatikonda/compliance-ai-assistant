# %%
import sys; sys.path.append("../")
from src.rag_pinecone.generation.rag_pipeline import rag_answer

query = "What is the functional requirements for Access and safety for firefighting operations?"
print(rag_answer(query))
# Out:
# [INFO] Searching knowledge base...
# The functional requirements for Access and safety for firefighting operations are:
#
# - Buildings must be designed and constructed so that there is a low probability of firefighters or other emergency services personnel being delayed in or impeded from assisting in rescue operations and performing firefighting operations (C5.1).
#
# - Buildings must be designed and constructed so that there is a low probability of illness or injury to firefighters or other emergency services personnel during rescue and firefighting operations (C5.2).
#
# - Buildings must be designed and constructed in a manner that will allow firefighters, taking into account their personal protective equipment and standard training, to:
#    (a) reach the floor of fire origin,
#    (b) search the general area of fire origin, and
#    (c) protect their means of egress.
#
# ...
