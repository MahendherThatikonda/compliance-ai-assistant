# %%
import sys; sys.path.append("../")
from src.rag_pinecone.generation.rag_pipeline import rag_answer

query = "What do the documents say about AI regulations?"
print(rag_answer(query))
# Out:
# [INFO] Searching knowledge base...
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[3], line 5
#       2 from src.rag_pinecone.generation.rag_pipeline import rag_answer
#       4 query = "What do the documents say about AI regulations?"
# ----> 5 print(rag_answer(query))
#
# File c:\Users\niros\OneDrive\Desktop\complaince-ai-assistant-foleys3\notebooks\..\src\rag_pinecone\generation\rag_pipeline.py:5, in rag_answer(query)
#       4 def rag_answer(query):
# ----> 5     matches = retrieve(query)
#       6     context = "\n\n".join(m.metadata["text"] for m in matches)
#       8     system = "Answer only using provided context. If unknown, say 'Not enough information'."
#
# File c:\Users\niros\OneDrive\Desktop\complaince-ai-assistant-foleys3\notebooks\..\src\rag_pinecone\retrieval\retriever.py:18, in retrieve(q)
#      16 def retrieve(q):
# ...
