# %%
# !pip install pinecone openai pypdf python-dotenv tqdm

# %%
import sys
print("Python version:", sys.version.split()[0])

import pinecone
print("pinecone version:", pinecone.__version__)
# Out:
# Python version: 3.12.12
# pinecone version: 8.0.0

# %%
import sys; sys.path.append("../")
from src.rag_pinecone.ingestion.index_builder import build_index_from_pdfs

build_index_from_pdfs()
# Out:
# [INFO] Using index: foleys-rag-index
# [INFO] Found 27 PDFs
# [INFO] Reading ../data/pdfs\AS NZS 2845.1.2010 backflow.pdf
# Indexing ../data/pdfs\AS NZS 2845.1.2010 backflow.pdf: 100%|██████████| 1/1 [00:07<00:00,  7.52s/it]
# [INFO] Reading ../data/pdfs\ASNZS-3500-12021 part 1.pdf
# Indexing ../data/pdfs\ASNZS-3500-12021 part 1.pdf: 100%|██████████| 11/11 [00:54<00:00,  4.91s/it]
# [INFO] Reading ../data/pdfs\ASNZS-3500-12025 (1).pdf
# Indexing ../data/pdfs\ASNZS-3500-12025 (1).pdf: 100%|██████████| 11/11 [00:32<00:00,  2.94s/it]
# [INFO] Reading ../data/pdfs\ASNZS-3500-22021 part 2.pdf
# Indexing ../data/pdfs\ASNZS-3500-22021 part 2.pdf: 100%|██████████| 17/17 [00:39<00:00,  2.35s/it]
# [INFO] Reading ../data/pdfs\ASNZS-3500-22025 (2).pdf
# Indexing ../data/pdfs\ASNZS-3500-22025 (2).pdf: 100%|██████████| 17/17 [00:39<00:00,  2.35s/it]
# [INFO] Reading ../data/pdfs\ASNZS-3500-32021 part 3.pdf
# ...
